# %%
path_prefix = '../..'

import sys
sys.path.append(path_prefix)

from egh_vlm.generate_answers import generate_answers

# %%
res = generate_answers(
    dataset_path=f'{path_prefix}/data/phd/prototype/phd_sample.json',
    img_folder_path=f'{path_prefix}/data/phd/images',
    prompt_path=f'{path_prefix}/data/phd/generate_v0.txt',
    save_path=f'{path_prefix}/data/phd/prototype/phd_sample_qwen3_vl_2b.json',
)
